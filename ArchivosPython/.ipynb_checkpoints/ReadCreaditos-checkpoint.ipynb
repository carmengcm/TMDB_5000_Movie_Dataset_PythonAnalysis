# %%
# IMPORTS
import pandas as pd
import json as js
from pandas.io.json import json_normalize

# %%
# Lectura de ficheros
file = "tmdb_5000_credits.csv"
file2 = "tmdb_5000_movies.csv"

credits = pd.read_csv(file, encoding="cp437", delimiter = ',')
movies = pd.read_csv(file2, encoding="cp437", delimiter = ',')

# %%
# Merge de Dataframes 

# Cambiamos el nombre a la columa del dataframe movies para poder hacer el merge.
movies = movies.rename(columns= {'id': 'movie_id'})

# Hacemos el merge
miMerge = pd.merge(credits, movies, on='movie_id')

# Montamos nuestro dataframe principal
dfPrincipal = miMerge[['movie_id','original_title', 'original_language', 'popularity', 'release_date', 'revenue',
             'runtime', 'status','vote_average','vote_count']]

# %%
# Montamos el dataframe de los casts 
df = miMerge[['movie_id', 'cast']]
#print(df['cast'][1])
miJson = pd.read_json(df['cast'][1])
print(len(df))
dfCasts = []

for i in range(len(df)):
    id = df['movie_id'][i]
    miJson = pd.read_json(df['cast'][i])
    # miJson.add(movie_i)
    print(range(len(miJson)))
    print("asdasd")
    #print(miJson.assign(movie_id = [id]))
    #dfCasts.append()
# Out:
# 4803
# range(0, 83)
# asdasd
# range(0, 34)
# asdasd
# range(0, 83)
# asdasd
# range(0, 158)
# asdasd
# range(0, 27)
# asdasd
# range(0, 143)
# asdasd
# range(0, 13)
# asdasd
# range(0, 72)
# asdasd
# range(0, 49)
# asdasd
# range(0, 152)
# asdasd
# range(0, 18)
# asdasd
# range(0, 32)
# asdasd
# range(0, 33)
# asdasd
# range(0, 60)
# asdasd
# range(0, 33)
# asdasd
# range(0, 21)
# asdasd
# range(0, 115)
# asdasd
# range(0, 35)
# asdasd
# range(0, 18)
# asdasd
# range(0, 42)
# asdasd
# range(0, 57)
# asdasd
# range(0, 34)
# asdasd
# range(0, 32)
# asdasd
# range(0, 29)
# asdasd
# range(0, 33)
# asdasd
# range(0, 136)
# asdasd
# range(0, 100)
# asdasd
# range(0, 46)
# asdasd
# range(0, 28)
# asdasd
# range(0, 24)
# asdasd
# range(0, 76)
# asdasd
# range(0, 107)
# asdasd
# range(0, 35)
# asdasd
# range(0, 32)
# asdasd
# range(0, 24)
# asdasd
# range(0, 37)
# asdasd
# range(0, 41)
# asdasd
# range(0, 159)
# asdasd
# range(0, 65)
# asdasd
# range(0, 23)
# asdasd
# range(0, 47)
# asdasd
# ...
